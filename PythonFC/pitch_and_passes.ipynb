# %%
import matplotlib.pyplot as plt

from matplotlib.patches import Arc

# %%
fig=plt.figure()
ax=fig.add_subplot()

plt.plot([0,0],[0,90], color="blue")
plt.plot([0,120],[90,90], color="orange")
plt.plot([120,120],[90,0], color="green")
plt.plot([120,0],[0,0], color="red")
plt.plot([60,60],[0,90], color="pink")
plt.plot([40,40],[0,90], color="aqua")
plt.plot([80,80],[0,90], color="maroon")
plt.plot([0,16],[25,25], color="k")
plt.plot([0,16],[65,65], color="k")
plt.plot([16,16],[25,65], color="k")
plt.plot([104,120],[25,25], color="k")
plt.plot([104,120],[65,65], color="k")
plt.plot([104,104],[25,65], color="k")

centreCircle = plt.Circle((60,45),9.15,color="red",fill=False)
centreSpot = plt.Circle((60,45),0.8,color="blue")
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="red")
rightArc = Arc((109,45),height=18.3,width=18.3,angle=90,theta1=35,theta2=145,color="orange")

ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftArc)
ax.add_patch(rightArc)

plt.show()

# %%
#function a bit editted by me
def createPitch(length, width):
    
    #Create figure
    fig=plt.figure()
    ax=fig.add_subplot()

    #Pitch Outline & Centre Line
    plt.plot([0,0],[0,width], color="black")
    plt.plot([0,length],[width,width], color="black")
    plt.plot([length,length],[width,0], color="black")
    plt.plot([length,0],[0,0], color="black")
    plt.plot([length/2,length/2],[0,width], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[width/2+20,width/2-20],color="black")
    plt.plot([0,16.5],[width/2+20,width/2+20],color="black")
    plt.plot([16.5,0],[width/2-20,width/2-20],color="black")
    
    #Right Penalty Area
    plt.plot([length,length-16.5],[width/2+20,width/2+20],color="black")
    plt.plot([length-16.5,length-16.5],[width/2+20,width/2-20],color="black")
    plt.plot([length-16.5,length],[width/2-20,width/2-20],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[width/2+9,width/2+9],color="black")
    plt.plot([5.5,5.5],[width/2+9,width/2-9],color="black")
    plt.plot([5.5,0],[width/2-9,width/2-9],color="black")
    
    #Right 6-yard Box
    plt.plot([length,length-5.5],[width/2+9,width/2+9],color="black")
    plt.plot([length-5.5,length-5.5],[width/2+9,width/2-9],color="black")
    plt.plot([length-5.5,length],[width/2-9,width/2-9],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((length/2,width/2),9.15,color="black",fill=False)
    centreSpot = plt.Circle((length/2,width/2),0.8,color="black")
    leftPenSpot = plt.Circle((11.5,width/2),0.8,color="black")
    rightPenSpot = plt.Circle((length-11.5,width/2),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,width/2),height=18.3,width=18.3,angle=0,theta1=305,theta2=55,color="black")
    rightArc = Arc((length-11,width/2),height=18.3,width=18.3,angle=0,theta1=125,theta2=235,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    #Tidy Axes
    plt.axis('off')
    
    #Display Pitch
    plt.show()
    
createPitch(105,68)

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("Data Store/passes.csv")

data.head()
# Out:
#          Half  Time Event   Player Team  Xstart  Ystart  Xend  Yend
# 0  First Half     1  Pass  Wombech  USA      26      38    66    52
# 1  First Half     6  Pass  Wombech  USA      81      34    62    68
# 2  First Half     6  Pass  Wombech  USA      46      45    84    63
# 3  First Half     8  Pass  Wombech  USA      89      66    89    39
# 4  First Half     9  Pass  Wombech  USA      68      64    21    25

# %%
fig, ax = plt.subplots()

for index, row in data.iterrows():
    plt.plot([row["Xstart"],row["Xend"]], [row["Ystart"], row["Yend"]], color="cyan")
    plt.plot(row["Xstart"], row["Ystart"], "o", color = "k")

def createPitch(length, width, figure, ax):
    
    #Create figure
    fig=figure
    ax=ax

    #Pitch Outline & Centre Line
    plt.plot([0,0],[0,width], color="black")
    plt.plot([0,length],[width,width], color="black")
    plt.plot([length,length],[width,0], color="black")
    plt.plot([length,0],[0,0], color="black")
    plt.plot([length/2,length/2],[0,width], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[width/2+20,width/2-20],color="black")
    plt.plot([0,16.5],[width/2+20,width/2+20],color="black")
    plt.plot([16.5,0],[width/2-20,width/2-20],color="black")
    
    #Right Penalty Area
    plt.plot([length,length-16.5],[width/2+20,width/2+20],color="black")
    plt.plot([length-16.5,length-16.5],[width/2+20,width/2-20],color="black")
    plt.plot([length-16.5,length],[width/2-20,width/2-20],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[width/2+9,width/2+9],color="black")
    plt.plot([5.5,5.5],[width/2+9,width/2-9],color="black")
    plt.plot([5.5,0],[width/2-9,width/2-9],color="black")
    
    #Right 6-yard Box
    plt.plot([length,length-5.5],[width/2+9,width/2+9],color="black")
    plt.plot([length-5.5,length-5.5],[width/2+9,width/2-9],color="black")
    plt.plot([length-5.5,length],[width/2-9,width/2-9],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((length/2,width/2),9.15,color="black",fill=False)
    centreSpot = plt.Circle((length/2,width/2),0.8,color="black")
    leftPenSpot = plt.Circle((11.5,width/2),0.8,color="black")
    rightPenSpot = plt.Circle((length-11.5,width/2),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,width/2),height=18.3,width=18.3,angle=0,theta1=305,theta2=55,color="black")
    rightArc = Arc((length-11,width/2),height=18.3,width=18.3,angle=0,theta1=125,theta2=235,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    #Tidy Axes
    plt.axis('off')
    
createPitch(120,70, fig, ax)
